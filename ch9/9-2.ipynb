# %%
from sklearn.decomposition import PCA, KernelPCA
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
features, _ = make_circles(n_samples=1000, random_state=1, noise=0.1, factor=0.1)

# %%
# データを可視化
plt.scatter(features[:, 0], features[:, 1])
plt.xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
# RBFカーネルを使用してKernel PCAを適用
kpca = KernelPCA(kernel="rbf", gamma=15, n_components=1)
features_kpca = kpca.fit_transform(features)

# %%
# 結果を表示
print("元の特徴量の形状:", features.shape)
print("PCA後の特徴量の形状:", features_kpca.shape)
# Out:
# 元の特徴量の形状: (1000, 2)
# PCA後の特徴量の形状: (1000, 1)

# %%
# カーネルPCAの結果を可視化
plt.scatter(features_kpca[:, 0], [0] * len(features_kpca), c='r', marker='x')
plt.xlabel("Kernel PCA Component")
# Out:
# Text(0.5, 0, 'Kernel PCA Component')
